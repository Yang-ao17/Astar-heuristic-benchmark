# %% [markdown]
# # A* Heuristic Benchmark Demo
#
# This notebook is an optional demo for the Python project. The core A* logic, heuristics, maps, metrics, and plotting functions live in the `src/` files. The demo runs the same budgeted benchmark used by `run_experiments.py`.

# %% [markdown]
# ## Project Import Setup

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif not (PROJECT_ROOT / "src").exists() and (PROJECT_ROOT.parent / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %% [markdown]
# ## Imports

# %%
from run_experiments import RESULT_COLUMNS, print_summary, run_benchmark
from src.heuristics import HEURISTICS
from src.visualization import plot_metric_bars, plot_paths_for_map

# %% [markdown]
# ## Run the Benchmark

# %%
selected_map_names = ["maze", "trap"]
max_expansions = 3000

results = run_benchmark(
    selected_map_names,
    HEURISTICS,
    max_expansions=max_expansions,
)

results[RESULT_COLUMNS]

# %% [markdown]
# ## Text Summary

# %%
print_summary(results)

# %% [markdown]
# ## Path Comparison Plots

# %%
for map_name in selected_map_names:
    plot_paths_for_map(map_name, results)

# %% [markdown]
# ## Metric Comparison Plots

# %%
for map_name in selected_map_names:
    plot_metric_bars(results, map_name, max_expansions=max_expansions)
